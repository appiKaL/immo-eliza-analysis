# %%
import pandas as pd 
import numpy as np
import re
# Out:
# /home/ridvan/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('/home/ridvan/Desktop/classes/immo-eliza-analysis/final_dataset.csv')

df
# Out:
#                                                       Url  BathroomCount  \
# 0       https://www.immoweb.be/en/classified/apartment...            1.0
# 1       https://www.immoweb.be/en/classified/house/for...            6.0
# 2       https://www.immoweb.be/en/classified/house/for...            2.0
# 3       https://www.immoweb.be/en/classified/house/for...            1.0
# 4       https://www.immoweb.be/en/classified/apartment...            0.0
# ...                                                   ...            ...
# 118709  https://www.immoweb.be/en/classified/house/for...            1.0
# 118710  https://www.immoweb.be/en/classified/house/for...            4.0
# 118711  https://www.immoweb.be/en/classified/apartment...            1.0
# 118712  https://www.immoweb.be/en/classified/apartment...            1.0
# 118713  https://www.immoweb.be/en/classified/apartment...            2.0
#
#         BedroomCount  ConstructionYear  Country  District  Fireplace  \
# 0                1.0            1969.0  Belgium    Brugge        NaN
# 1               13.0            1920.0  Belgium   Tournai        NaN
# 2                4.0            2008.0  Belgium    Brugge        NaN
# 3                4.0               NaN  Belgium    Veurne        NaN
# 4                2.0            1972.0  Belgium   Hasselt        NaN
# ...              ...               ...      ...       ...        ...
# 118709           3.0            2024.0  Belgium      Gent        NaN
# 118710           4.0               NaN  Belgium   Antwerp        NaN
# 118711           2.0               NaN  Belgium   Antwerp        NaN
# 118712           2.0               NaN  Belgium    Brugge        NaN
# 118713           3.0               NaN  Belgium  Brussels        NaN
#
#                FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 0                       NaN        NaN     NaN  ...        1.0         0.0
# 1                       NaN        0.0     NaN  ...       31.0         NaN
# 2            NON_FLOOD_ZONE        1.0     NaN  ...        NaN         0.0
# 3                       NaN        NaN     1.0  ...        NaN         NaN
# 4            NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
# ...                     ...        ...     ...  ...        ...         ...
# 118709                  NaN        NaN     1.0  ...        4.0         NaN
# 118710                  NaN        0.0     NaN  ...        NaN         NaN
# 118711       NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
# 118712  POSSIBLE_FLOOD_ZONE        NaN     NaN  ...        8.0         NaN
# 118713       NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
#
#         StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool  \
# 0                  GOOD       flat_studio            NaN           NaN
# 1                  GOOD   apartment_block          130.0           NaN
# 2                  GOOD             house            0.0           NaN
# 3         TO_BE_DONE_UP             house          170.0           0.0
# 4                AS_NEW         apartment            NaN           NaN
# ...                 ...               ...            ...           ...
# 118709             GOOD             house          234.0           NaN
# 118710   JUST_RENOVATED   apartment_block          202.0           NaN
# 118711             GOOD         apartment            NaN           0.0
# 118712              NaN         apartment            NaN           NaN
# 118713             GOOD         apartment            NaN           NaN
#
#        Terrace  ToiletCount  TypeOfProperty                TypeOfSale
# 0          1.0          1.0               2          residential_sale
# 1          NaN          5.0               1          residential_sale
# 2          NaN          2.0               1          residential_sale
# 3          1.0          2.0               1          residential_sale
# 4          1.0          1.0               2          residential_sale
# ...        ...          ...             ...                       ...
# 118709     NaN          0.0               1          residential_sale
# 118710     NaN          NaN               1          residential_sale
# 118711     1.0          1.0               2          residential_sale
# 118712     1.0          NaN               2          residential_sale
# 118713     1.0          3.0               2  residential_monthly_rent
#
# [118714 rows x 32 columns]

# %%
filtered = df[pd.notna(df['MonthlyCharges'])]
filtered
# Out:
#                                                       Url  BathroomCount  \
# 6       https://www.immoweb.be/en/classified/house/for...            4.0
# 11      https://www.immoweb.be/en/classified/apartment...            1.0
# 23      https://www.immoweb.be/en/classified/apartment...            1.0
# 95      https://www.immoweb.be/en/classified/apartment...            1.0
# 170     https://www.immoweb.be/en/classified/house/for...            4.0
# ...                                                   ...            ...
# 118645  https://www.immoweb.be/en/classified/apartment...            1.0
# 118658  https://www.immoweb.be/en/classified/apartment...            1.0
# 118692  https://www.immoweb.be/en/classified/house/for...            1.0
# 118706  https://www.immoweb.be/en/classified/apartment...            1.0
# 118713  https://www.immoweb.be/en/classified/apartment...            2.0
#
#         BedroomCount  ConstructionYear  Country  District  Fireplace  \
# 6                6.0            1970.0  Belgium  Nivelles        1.0
# 11               3.0               NaN  Belgium  Brussels        NaN
# 23               0.0               NaN  Belgium  Brussels        NaN
# 95               1.0            1920.0  Belgium  Brussels        NaN
# 170              6.0               NaN  Belgium  Brussels        NaN
# ...              ...               ...      ...       ...        ...
# 118645           2.0            1989.0  Belgium    Brugge        1.0
# 118658           1.0            2014.0  Belgium   Antwerp        NaN
# 118692           2.0            1899.0  Belgium      Gent        NaN
# 118706           1.0            1971.0  Belgium  Mouscron        NaN
# 118713           3.0               NaN  Belgium  Brussels        NaN
#
#           FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 6       NON_FLOOD_ZONE        NaN     1.0  ...        NaN         0.0
# 11      NON_FLOOD_ZONE        NaN     NaN  ...        6.0         2.0
# 23                 NaN        NaN     NaN  ...        NaN         1.0
# 95                 NaN        NaN     NaN  ...        NaN         NaN
# 170     NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
# ...                ...        ...     ...  ...        ...         ...
# 118645  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         1.0
# 118658  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         0.0
# 118692  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
# 118706             NaN        NaN     NaN  ...        NaN         1.0
# 118713  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
#
#         StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool  \
# 6                  GOOD             villa         2519.0           NaN
# 11                 GOOD         apartment            NaN           0.0
# 23       JUST_RENOVATED       flat_studio            NaN           NaN
# 95                  NaN            duplex            NaN           NaN
# 170              AS_NEW             villa            0.0           1.0
# ...                 ...               ...            ...           ...
# 118645             GOOD         apartment            NaN           0.0
# 118658             GOOD         apartment            NaN           NaN
# 118692           AS_NEW             house            0.0           NaN
# 118706             GOOD         apartment            NaN           NaN
# 118713             GOOD         apartment            NaN           NaN
#
#        Terrace  ToiletCount  TypeOfProperty                TypeOfSale
# 6          1.0          5.0               1  residential_monthly_rent
# 11         1.0          3.0               2  residential_monthly_rent
# 23         NaN          1.0               2  residential_monthly_rent
# 95         1.0          NaN               2  residential_monthly_rent
# 170        1.0          6.0               1  residential_monthly_rent
# ...        ...          ...             ...                       ...
# 118645     NaN          1.0               2  residential_monthly_rent
# 118658     1.0          1.0               2  residential_monthly_rent
# 118692     NaN          2.0               1  residential_monthly_rent
# 118706     NaN          1.0               2  residential_monthly_rent
# 118713     1.0          3.0               2  residential_monthly_rent
#
# [13650 rows x 32 columns]

# %%
filtered2 = df[df.TypeOfSale != 'residential_sale']
filtered2
# Out:
#                                                       Url  BathroomCount  \
# 6       https://www.immoweb.be/en/classified/house/for...            4.0
# 11      https://www.immoweb.be/en/classified/apartment...            1.0
# 23      https://www.immoweb.be/en/classified/apartment...            1.0
# 95      https://www.immoweb.be/en/classified/apartment...            1.0
# 170     https://www.immoweb.be/en/classified/house/for...            4.0
# ...                                                   ...            ...
# 118645  https://www.immoweb.be/en/classified/apartment...            1.0
# 118658  https://www.immoweb.be/en/classified/apartment...            1.0
# 118692  https://www.immoweb.be/en/classified/house/for...            1.0
# 118706  https://www.immoweb.be/en/classified/apartment...            1.0
# 118713  https://www.immoweb.be/en/classified/apartment...            2.0
#
#         BedroomCount  ConstructionYear  Country  District  Fireplace  \
# 6                6.0            1970.0  Belgium  Nivelles        1.0
# 11               3.0               NaN  Belgium  Brussels        NaN
# 23               0.0               NaN  Belgium  Brussels        NaN
# 95               1.0            1920.0  Belgium  Brussels        NaN
# 170              6.0               NaN  Belgium  Brussels        NaN
# ...              ...               ...      ...       ...        ...
# 118645           2.0            1989.0  Belgium    Brugge        1.0
# 118658           1.0            2014.0  Belgium   Antwerp        NaN
# 118692           2.0            1899.0  Belgium      Gent        NaN
# 118706           1.0            1971.0  Belgium  Mouscron        NaN
# 118713           3.0               NaN  Belgium  Brussels        NaN
#
#           FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 6       NON_FLOOD_ZONE        NaN     1.0  ...        NaN         0.0
# 11      NON_FLOOD_ZONE        NaN     NaN  ...        6.0         2.0
# 23                 NaN        NaN     NaN  ...        NaN         1.0
# 95                 NaN        NaN     NaN  ...        NaN         NaN
# 170     NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
# ...                ...        ...     ...  ...        ...         ...
# 118645  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         1.0
# 118658  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         0.0
# 118692  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
# 118706             NaN        NaN     NaN  ...        NaN         1.0
# 118713  NON_FLOOD_ZONE        NaN     NaN  ...        NaN         NaN
#
#         StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool  \
# 6                  GOOD             villa         2519.0           NaN
# 11                 GOOD         apartment            NaN           0.0
# 23       JUST_RENOVATED       flat_studio            NaN           NaN
# 95                  NaN            duplex            NaN           NaN
# 170              AS_NEW             villa            0.0           1.0
# ...                 ...               ...            ...           ...
# 118645             GOOD         apartment            NaN           0.0
# 118658             GOOD         apartment            NaN           NaN
# 118692           AS_NEW             house            0.0           NaN
# 118706             GOOD         apartment            NaN           NaN
# 118713             GOOD         apartment            NaN           NaN
#
#        Terrace  ToiletCount  TypeOfProperty                TypeOfSale
# 6          1.0          5.0               1  residential_monthly_rent
# 11         1.0          3.0               2  residential_monthly_rent
# 23         NaN          1.0               2  residential_monthly_rent
# 95         1.0          NaN               2  residential_monthly_rent
# 170        1.0          6.0               1  residential_monthly_rent
# ...        ...          ...             ...                       ...
# 118645     NaN          1.0               2  residential_monthly_rent
# 118658     1.0          1.0               2  residential_monthly_rent
# 118692     NaN          2.0               1  residential_monthly_rent
# 118706     NaN          1.0               2  residential_monthly_rent
# 118713     1.0          3.0               2  residential_monthly_rent
#
# [13766 rows x 32 columns]

# %%
new_value = int(df['NumberOfFacades'].mean())

df['NumberOfFacades'].fillna(new_value , inplace = True)

df.head()
# Out:
# /tmp/ipykernel_48874/2295466160.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NumberOfFacades'].fillna(new_value , inplace = True)
#                                                  Url  BathroomCount  \
# 0  https://www.immoweb.be/en/classified/apartment...            1.0
# 1  https://www.immoweb.be/en/classified/house/for...            6.0
# 2  https://www.immoweb.be/en/classified/house/for...            2.0
# 3  https://www.immoweb.be/en/classified/house/for...            1.0
# 4  https://www.immoweb.be/en/classified/apartment...            0.0
#
#    BedroomCount  ConstructionYear  Country District  Fireplace  \
# 0           1.0            1969.0  Belgium   Brugge        NaN
# 1          13.0            1920.0  Belgium  Tournai        NaN
# 2           4.0            2008.0  Belgium   Brugge        NaN
# 3           4.0               NaN  Belgium   Veurne        NaN
# 4           2.0            1972.0  Belgium  Hasselt        NaN
#
#      FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 0             NaN        NaN     NaN  ...        1.0         0.0
# 1             NaN        0.0     NaN  ...       31.0         NaN
# 2  NON_FLOOD_ZONE        1.0     NaN  ...        NaN         0.0
# 3             NaN        NaN     1.0  ...        NaN         NaN
# 4  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
#
#    StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool Terrace  \
# 0             GOOD       flat_studio            NaN           NaN     1.0
# 1             GOOD   apartment_block          130.0           NaN     NaN
# 2             GOOD             house            0.0           NaN     NaN
# 3    TO_BE_DONE_UP             house          170.0           0.0     1.0
# 4           AS_NEW         apartment            NaN           NaN     1.0
#
#    ToiletCount  TypeOfProperty        TypeOfSale
# 0          1.0               2  residential_sale
# 1          5.0               1  residential_sale
# 2          2.0               1  residential_sale
# 3          2.0               1  residential_sale
# 4          1.0               2  residential_sale
#
# [5 rows x 32 columns]

# %%
under_1945_peb = df[df['ConstructionYear'] < 1945]
most_common_peb_class = under_1945_peb['PEB'].mode()[0] 
print(most_common_peb_class)

bellow_1945_peb = df[df['ConstructionYear'] > 1945]
most_common_peb_class_bellow = bellow_1945_peb['PEB'].mode()[0]
print(most_common_peb_class_bellow)
# Out:
# F
# B

# %%
df['PEB'] = np.where(
    pd.isna(df['PEB']) & (df['ConstructionYear'] < 1945), most_common_peb_class,
    np.where(
        pd.isna(df['PEB']) & (df['ConstructionYear'] > 1945), most_common_peb_class_bellow,
        df['PEB']
    )
)

df['PEB'] = df['PEB'].fillna('F', axis=None)

# %%
df.head()
# Out:
#                                                  Url  BathroomCount  \
# 0  https://www.immoweb.be/en/classified/apartment...            1.0
# 1  https://www.immoweb.be/en/classified/house/for...            6.0
# 2  https://www.immoweb.be/en/classified/house/for...            2.0
# 3  https://www.immoweb.be/en/classified/house/for...            1.0
# 4  https://www.immoweb.be/en/classified/apartment...            0.0
#
#    BedroomCount  ConstructionYear  Country District  Fireplace  \
# 0           1.0            1969.0  Belgium   Brugge        NaN
# 1          13.0            1920.0  Belgium  Tournai        NaN
# 2           4.0            2008.0  Belgium   Brugge        NaN
# 3           4.0               NaN  Belgium   Veurne        NaN
# 4           2.0            1972.0  Belgium  Hasselt        NaN
#
#      FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 0             NaN        NaN     NaN  ...        1.0         0.0
# 1             NaN        0.0     NaN  ...       31.0         NaN
# 2  NON_FLOOD_ZONE        1.0     NaN  ...        NaN         0.0
# 3             NaN        NaN     1.0  ...        NaN         NaN
# 4  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
#
#    StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool Terrace  \
# 0             GOOD       flat_studio            NaN           NaN     1.0
# 1             GOOD   apartment_block          130.0           NaN     NaN
# 2             GOOD             house            0.0           NaN     NaN
# 3    TO_BE_DONE_UP             house          170.0           0.0     1.0
# 4           AS_NEW         apartment            NaN           NaN     1.0
#
#    ToiletCount  TypeOfProperty        TypeOfSale
# 0          1.0               2  residential_sale
# 1          5.0               1  residential_sale
# 2          2.0               1  residential_sale
# 3          2.0               1  residential_sale
# 4          1.0               2  residential_sale
#
# [5 rows x 32 columns]
